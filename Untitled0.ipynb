# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasanthsrinivas/twitter-scrapping/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 3.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
query = "(datascience) until:2023-01-15 since:2022-10-11"
tweets=[]
limit=1000

# %%
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
  if len(tweets)==limit:
    break
  else:
    tweets.append([tweet.date , tweet.id ,tweet.url ,tweet.user.username ,tweet.user.location ,tweet.content ,tweet.source ,tweet.retweetCount,tweet.likeCount ,tweet.replyCount,tweet.lang])
  
df = pd.DataFrame(tweets,columns=["Date", "Tweetid","tweet url", "username", "location","content","source", "retweetcount",  "likecount ","replycount","language"])
df
# Out:
# <ipython-input-14-841ec795257d>:5: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date , tweet.id ,tweet.url ,tweet.user.username ,tweet.user.location ,tweet.content ,tweet.source ,tweet.retweetCount,tweet.likeCount ,tweet.replyCount,tweet.lang])
#                          Date              Tweetid  \
# 0   2023-01-14 23:55:34+00:00  1614410929499668481
# 1   2023-01-14 23:55:09+00:00  1614410826131161088
# 2   2023-01-14 23:53:47+00:00  1614410479807664130
# 3   2023-01-14 23:50:58+00:00  1614409773361041408
# 4   2023-01-14 23:49:49+00:00  1614409481261121537
# ..                        ...                  ...
# 995 2023-01-14 09:07:49+00:00  1614187518995349505
# 996 2023-01-14 09:07:30+00:00  1614187439031033857
# 997 2023-01-14 09:06:50+00:00  1614187271145619458
# 998 2023-01-14 09:06:48+00:00  1614187263767859201
# 999 2023-01-14 09:06:08+00:00  1614187097216221184
#
# ...

# %%
a=pd.read_csv("/content/tweets")
a
# Out:
#      Unnamed: 0                       Date              Tweetid  \
# 0             0  2023-01-14 23:55:34+00:00  1614410929499668481
# 1             1  2023-01-14 23:55:09+00:00  1614410826131161088
# 2             2  2023-01-14 23:53:47+00:00  1614410479807664130
# 3             3  2023-01-14 23:50:58+00:00  1614409773361041408
# 4             4  2023-01-14 23:49:49+00:00  1614409481261121537
# ..          ...                        ...                  ...
# 995         995  2023-01-14 09:07:49+00:00  1614187518995349505
# 996         996  2023-01-14 09:07:30+00:00  1614187439031033857
# 997         997  2023-01-14 09:06:50+00:00  1614187271145619458
# 998         998  2023-01-14 09:06:48+00:00  1614187263767859201
# 999         999  2023-01-14 09:06:08+00:00  1614187097216221184
#
#                                              tweet url         username  \
# 0    https://twitter.com/KirkDBorne/status/16144109...       KirkDBorne
# ...

# %%
df=a.to_csv("tweets")
df

# %%
a_dict=a.to_dict("records")
print(a_dict)
# Out:
# [{'Unnamed: 0': 0, 'Date': '2023-01-14 23:55:34+00:00', 'Tweetid': 1614410929499668481, 'tweet url': 'https://twitter.com/KirkDBorne/status/1614410929499668481', 'username': 'KirkDBorne', 'location': 'Maryland, USA', 'content': '#MachineLearning and #DeepLearning Papers Explained — project by @RitvikRastogi19 on @dair_ai — https://t.co/OgBD57hofD HT @omarsar0 \n————\n#BigData #DataScience #AI #ML #DataScientist #NeuralNetworks #Algorithms #Mathematics https://t.co/UG6QGzDifP', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'retweetcount': 16, 'likecount ': 31, 'replycount': 0, 'language': 'en'}, {'Unnamed: 0': 1, 'Date': '2023-01-14 23:55:09+00:00', 'Tweetid': 1614410826131161088, 'tweet url': 'https://twitter.com/HackwithNichola/status/1614410826131161088', 'username': 'HackwithNichola', 'location': 'California', 'content': 'Can companies make decisions with AI?\n\n📌https://t.co/8cNN6XrDD0\n\n#MachineLearning #AI #Python #DataScience 
# ...

# %%
pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pymongo import MongoClient

# %%
py=MongoClient("mongodb://Guvi:<pass>@ac-wadx12y-shard-00-00.fr2x1n6.mongodb.net:27017,ac-wadx12y-shard-00-01.fr2x1n6.mongodb.net:27017,ac-wadx12y-shard-00-02.fr2x1n6.mongodb.net:27017/?ssl=true&replicaSet=atlas-jltwa6-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
pytweet=py["twitterscrapping"]
pycollection=pytweet["tweets"]
pycollection.insert_many(a_dict)
